# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
# %matplotlib inline
k = 1
x = [i for i in range(50)]
y = [math.cos(k*i) for i in x]
plt.plot(x,y)

# %%
k = 4
y = [math.cos(k*i) for i in x]
plt.plot(x,y)
