# %% [markdown]
# **Задание 1.** Найти вероятность выпадения 2 или 5 очков при подбрасывании игральной кости, на гранях которой имеются соответственно 1,2,3,4,5 и 6 очков.
#
# **Решение**
#
# Нас удовлетворяют два варианта, это {выпадение 2-ки или 5-ки}. Соответственно вычисляться будет как отношение балгоприятных исходов к общему количеству:
#
# $Р_{\text{{выпадение 2-ки или 5-ки}}}=\frac{2}{6}≈0,33$

# %% [markdown]
# **Задание 2** Найти вероятность того, что при двух подбрасываниях той же самой игральной кости сначала выпадет 2, а затем 5.
#
# **Решение**
# Вероятность выпадения 2-ки:
# $P_{2} = \frac{1}{6}$
#
# Вероятность выпадения 5-ки:
# $P_{5} = \frac{1}{6}$
#
# Вероятность выпадения {сначала 2, а затем 5}:
# $P_{\text{{2->5}}} = \frac{1}{6} * \frac{1}{6} = \frac{1}{36}$
# Потому что только один благоприятный исход

# %% [markdown]
# **Задание 3.** Найти вероятность выпадения 2 и 5 очков при двух подбрасываниях той же самой игральной игральной кости.

# %% [markdown]
# **Решение.**
# В этом условии отсутствует указание порядка выпадения результатов которые нам необходимо соблюдать, это значит что необходимо рассмотреть оба варианта {выпало 2 потом 5} и {выпало 5 потом 2}. Вероятности выпадения каждой из этих ситуаций рассчитываются как:
#
# $P_{\text{{2->5}}} = \frac{1}{6} * \frac{1}{6} = \frac{1}{36}$
#
# $P_{\text{{5->2}}} = \frac{1}{6} * \frac{1}{6} = \frac{1}{36}$
#
# Полная вероятность соответственно будет равна сумме вероятностей этих событий:
#
# $P_{\text{полн.}} = \frac{1}{36} + \frac{1}{36} = \frac{1}{18}$

# %% [markdown]
# **Задание 4.** На отрезке AB длиной 20 см наугад отметили точку C. Какова вероятность, что она находится на расстоянии не более 9 см от точки А и не более 15 см от точки В?

# %% [markdown]
# **Решение.**
# Найдем длину отрезка на который приходится местоположение точки С удовлетворяющее условию.
#
# (15+9) - 20 = 4(см)
#
# Теперь нас интересует какова вероятность попадания в этот промежуток относительно общей длины отрезка.
# P = 4/20 = 0.2

# %% [markdown]
# **Задание 5.** Телефонный номер состоит из 7 цифр. Какова вероятность, что это номер 8882777?

# %% [markdown]
# **Решение.**
# Вариант который бы удовлетворял условиям здесь единственный, значит необходимо определить общее количество возможных комбинаций цифр в номере. Так как номер не может начинаться с нуля, то:
# $P = \frac{1}{9*10^6}$

# %% [markdown]
# **Задание 6.** Набирая номер телефона, абонент забыл 2 последние цифры, и, помня только то, что эти цифры различны и среди них нет нуля, стал набирать их наудачу. Сколько вариантов ему надо перебрать, чтобы наверняка найти нужный номер? Какова вероятность того, что он угадает номер с первого раза?

# %% [markdown]
# **Решение**
# Посчитаем количество возможных вариантов $A_9^2 = \frac{9!}{7!} = 72$. Т.о. вероятность найти нужный номер будет $\frac{1}{72}$
